# %%
from src.domain.RawDataframeRequest import RawDataframeRequest
from src.services.RawDataframeService import RawDataframeService
from src.services.RawService import RawService
from src.services.IsobusService import IsobusService
rawDataframService = RawDataframeService()
from datetime import datetime,timedelta
import time
import pandas as pd
import os
from termcolor import colored
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib.ticker import FixedFormatter, FixedLocator
import matplotlib.dates as mdates
import seaborn as sn
import pandas as pd
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn import datasets
from joblib import dump, load
# Out:
# 'data_representation'
# Falha em se conectar ao banco de dados

# %%
bucket = 'iotag-vehicles-logs'
dictionary_to_use = 'AXIAL_FLOW_CASE'
dictionary_to_use = 'IOTAG'

# %%
file_sniffer = ''

file_list = [
'9AGC1014VNS000068_4C7525BD4142_240125_123931_216150_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_114745_216149_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_125210_216151_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_131755_216152_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_132824_216153_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_133439_216154_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_135156_216155_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_140927_216156_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_142509_216157_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_144249_216158_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_151249_216159_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_152557_216160_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_161118_216161_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_162552_216162_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_165313_216163_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_174114_216164_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_174703_216165_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_181603_216166_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_183949_216167_RAW.zip',
'9AGC1014VNS000068_4C7525BD4142_240125_185543_216168_RAW.zip']

#orion
file_list=[
#dias de treinamento

 #dia 24/04
'1L06130RKNP143809_4C7525BDDB22_240424_070231_35046_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_073231_35047_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_080231_35048_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_083231_35049_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_084920_35050_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_091700_35051_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_094659_35052_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_101658_35053_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_111657_35055_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_104657_35054_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_114657_35056_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_131508_35059_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_150157_35063_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_124657_35058_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_134227_35060_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_121657_35057_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_141019_35061_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_143459_35062_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_153058_35064_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_155246_35065_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_161429_35066_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_163606_35067_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_164724_35068_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_171047_35069_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_173610_35070_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_180609_35071_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_183608_35072_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240424_190607_35073_RAW.zip',

## dia 25/04
'1L06130RKNP143809_4C7525BDDB22_240425_054615_35074_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_060159_35075_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_060827_35076_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_063826_35077_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_070826_35078_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_073826_35079_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_080825_35080_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_083824_35081_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_090823_35082_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_093822_35083_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_100821_35084_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_110134_35085_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_110511_35086_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_121414_35087_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_124413_35088_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_131412_35089_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240425_134411_35090_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_141410_35091_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_144409_35092_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_151408_35093_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240425_161358_35094_RAW.zip',

## dia 30/04 (bom)
'1L06130RKNP143809_4C7525BDDB22_240430_054832_35096_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_102739_35097_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_104555_35098_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_111555_35099_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_114555_35100_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_120840_35101_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_123717_35102_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_130514_35103_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_132846_35104_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_135701_35105_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_142405_35106_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_143150_35107_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_145527_35108_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_151959_35109_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_154419_35110_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_161418_35111_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_164417_35112_RAW.zip',	
'1L06130RKNP143809_4C7525BDDB22_240430_171416_35113_RAW.zip',

   
# #dia 10/05 (legal)
'1L06130RKNP143809_4C7525BDDB22_240509_095335_35147_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_083438_35148_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_091131_35149_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_095358_35150_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_102858_35151_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_105858_35152_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_112857_35153_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_115856_35154_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_122855_35155_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_125854_35156_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_132854_35157_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_135853_35158_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_142853_35159_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_145853_35160_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_152852_35161_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_155851_35162_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_161510_35163_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_164509_35164_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_164540_35165_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_165150_35166_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_172149_35167_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_172508_35168_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_175507_35169_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_182506_35170_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_185506_35171_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_191936_35172_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_194741_35173_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_201210_35174_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_203538_35175_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_210054_35176_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_211041_35177_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_213050_35178_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_220049_35179_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_223049_35180_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_230048_35181_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_233047_35182_RAW.zip',
'1L06130RKNP143809_4C7525BDDB22_240510_235858_35183_RAW.zip',
   
##dia 28/05 (mais ou menos)
#'1L06130RKNP143809_4C7525BDDB22_240528_153104_35377_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_140107_35374_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_094412_35373_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_093834_35372_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_090514_35371_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_082842_35370_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_075843_35369_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_073448_35368_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_070449_35367_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_063542_35366_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_060912_35365_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_054410_35364_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_051847_35363_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240528_045251_35362_RAW.zip',
#
## dia 27/05 (mais ou menos)
#'1L06130RKNP143809_4C7525BDDB22_240527_222953_35361_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_220338_35360_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_213432_35359_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_212308_35358_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_205914_35357_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_203410_35356_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_200441_35355_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_193657_35354_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_191126_35353_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_184417_35352_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_181812_35351_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_174812_35350_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_171813_35349_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_164814_35348_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_161815_35347_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_154816_35346_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_151816_35345_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_144817_35344_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_141817_35343_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_134817_35342_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_133446_35341_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_131110_35340_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_124522_35339_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_121522_35338_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_114522_35337_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_111523_35336_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_103850_35335_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_100851_35334_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_093851_35333_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_091342_35332_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_090245_35331_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240527_083246_35330_RAW.zip',
#
##dia 15/05 (bom)
#'1L06130RKNP143809_4C7525BDDB22_240515_194932_35254_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_192531_35253_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_190036_35252_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_183543_35251_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_163049_35250_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_155714_35249_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_091830_35248_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_084853_35247_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_081853_35246_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_080758_35245_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_073954_35244_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_070954_35243_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_063954_35242_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240515_060954_35241_RAW.zip',
#
##dia 6/06 (bom)
#
#'1L06130RKNP143809_4C7525BDDB22_240606_195514_35508_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_192757_35507_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_190310_35506_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_183845_35505_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_181330_35504_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_174815_35503_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_171815_35502_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_170416_35501_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_163855_35500_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_163125_35499_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_160709_35498_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_154242_35497_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_151243_35496_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_144244_35495_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_141738_35494_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_135043_35493_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_132043_35492_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_130807_35491_RAW.zip',
#'1L06130RKNP143809_4C7525BDDB22_240606_125126_35490_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_122324_35489_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_115618_35488_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_113012_35487_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_110431_35486_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_103919_35485_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_101129_35484_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_094130_35483_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_092226_35482_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_090650_35481_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_085646_35480_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_082647_35479_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_075647_35478_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_072647_35477_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_065648_35476_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_062648_35475_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_060322_35474_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_054908_35473_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_051908_35472_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_044909_35471_RAW.zip',	
#'1L06130RKNP143809_4C7525BDDB22_240606_041303_35470_RAW.zip'
]


file_list = [
'9AGT2023KNC001892_4C7525BDDF62_240617_114505_6620078_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_141520_6620079_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_142548_6620080_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_144232_6620081_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_151232_6620082_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_154232_6620083_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_161232_6620084_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_164232_6620085_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_171232_6620086_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_174232_6620087_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_181308_6620088_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_184308_6620089_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_191308_6620090_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_194308_6620091_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_201308_6620092_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240617_204308_6620093_RAW.zip',
]

#file_list = [
#'AVTT2005VFM021754_4C7525BEC31A_240123_103046_218_RAW.zip',
#'AVTT2005VFM021754_4C7525BEC31A_240123_105019_219_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_110340_220_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_113340_221_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_120340_222_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_123340_223_RAW.zip',
#'AVTT2005VFM021754_4C7525BEC31A_240123_130340_224_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_133340_225_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_140340_226_RAW.zip',
#'AVTT2005VFM021754_4C7525BEC31A_240123_152033_227_RAW.zip',
#'AVTT2005VFM021754_4C7525BEC31A_240123_152629_228_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_155631_229_RAW.zip',
#'AVTT2005VFM021754_4C7525BEC31A_240123_161035_230_RAW.zip',
#'AVTT2005VFM021754_4C7525BEC31A_240123_164035_231_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_171035_232_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_174035_233_RAW.zip',
#'AVTT2005VFM021754_4C7525BEC31A_240123_181035_234_RAW.zip',	
#'AVTT2005VFM021754_4C7525BEC31A_240123_184035_235_RAW.zip',
#]

file_list = [
'9AGT2023KNC001892_4C7525BDDF62_240607_131401_6619989_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_134401_6619990_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_141401_6619991_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_144401_6619992_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_152723_6619993_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_162446_6619995_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_175037_6619997_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_182037_6619998_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_185037_6619999_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_190821_6620000_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_155446_6619994_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_172037_6619996_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_192345_6620001_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_195346_6620002_RAW.zip',
'9AGT2023KNC001892_4C7525BDDF62_240607_200444_6620003_RAW.zip',
]

#file_list = [
#'9AGT2023KNC001892_4C7525BDDF62_240608_110452_6620004_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_111253_6620005_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_114253_6620006_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_121253_6620007_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_124253_6620008_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_131253_6620009_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_134253_6620010_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_142152_6620011_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_145152_6620012_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_152152_6620013_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_155152_6620014_RAW.zip',
#'9AGT2023KNC001892_4C7525BDDF62_240608_163504_6620015_RAW.zip',
#]

file_list = [
'0007504509M000971_4C7525BEC46A_240207_102701_340_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_103450_341_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_105539_342_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_110234_343_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_110650_344_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_113650_345_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_114846_346_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_121847_347_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_124847_348_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_131847_349_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_134847_350_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_141848_351_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_143048_352_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_153106_353_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_154013_354_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_161014_355_RAW.zip',
'0007504509M000971_4C7525BEC46A_240207_163415_356_RAW.zip',
]




#file_list = [
#'RR0171B560767D_D8A01D55C9A2_220816_162021_579_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_160342_578_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_160111_577_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_155533_576_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_152254_575_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_150703_574_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_130233_573_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_123233_572_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_115055_571_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_112055_570_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_060303_569_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_060159_568_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_053400_567_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_050400_566_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_042541_565_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_035541_564_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_032751_563_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_030616_562_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_023616_561_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_023549_560_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_021640_559_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_010210_558_RAW.zip',
#'RR0171B560767D_D8A01D55C9A2_220816_010139_557_RAW.zip',
#] 

file_list = [

'RR0171B560767D_D8A01D55C4EA_220820_180351_173_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_180201_172_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_174831_171_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_172046_170_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_165432_169_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_162432_168_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_155833_167_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_152833_166_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_152513_165_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_150327_164_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_132427_163_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_125427_162_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_124230_161_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_123419_160_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_120419_159_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_113419_158_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_055101_157_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_054708_156_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_052601_155_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_045601_154_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_042031_153_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_040756_152_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_033756_151_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_030504_150_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_023504_149_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_023207_148_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_022933_147_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_022007_146_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_020039_145_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_012437_144_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_005816_143_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_005346_142_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_004737_141_RAW.zip',
'RR0171B560767D_D8A01D55C4EA_220820_003014_140_RAW.zip',
] 

file_list =[
'RWMDN8B100213_4C7525BDDF46_240131_092056_738_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_095238_739_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_102237_740_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_105237_741_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_105617_742_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_112617_743_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_115617_744_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_122617_745_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_125617_746_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_131316_747_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_142449_748_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_152416_749_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_155225_750_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_162225_751_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_165224_752_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_172224_753_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_175223_754_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_182223_755_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_185223_756_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_192223_757_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_192958_758_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_195957_759_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_202957_760_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_205957_761_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_212956_762_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_215956_763_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_220745_764_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_223745_765_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_224534_766_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_231534_767_RAW.zip',
'RWMDN8B100213_4C7525BDDF46_240131_232239_768_RAW.zip']

file_list = [
'PRCY8800KHPA03117_4C7525BE2A8E_240716_094255_2287_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_091923_2286_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_084923_2285_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_081923_2284_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_074923_2283_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_071923_2282_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_070631_2281_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_064021_2280_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_061211_2279_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_054211_2278_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_051211_2277_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_050754_2276_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_045259_2275_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_042259_2274_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_035606_2273_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_032606_2272_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_031211_2271_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_030646_2270_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_023646_2269_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_020646_2268_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_013646_2267_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_011547_2266_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_004300_2265_RAW.zip',
'PRCY8800KHPA03117_4C7525BE2A8E_240716_001300_2264_RAW.zip',
]

# %%
##%%capture captured
#Baixa os arquivos da AWS e processa os arquivos
parsed_raw = []
if file_sniffer == '':
    for file in file_list:
        request = RawDataframeRequest((("{\"file_name\":\"#file#\", \"bucket\":\"#bucket#\", \"dictionary_to_use\":\"#dicionario#\"}").replace('#file#',file).replace('#bucket#',bucket).replace('#dicionario#',dictionary_to_use)))
        rawDataframService.download_file(request, '')
        try:
            rawDataframService.unzip_file(request, '')
        except:
            print('Erro em descompactar o arquivo:', file)
            continue
        #print(file)
        rawService = RawService(request, rawDataframService.path, rawDataframService.dictionaryService)
        self = rawService
        
        parsed_raw_actual = self.read_binary_raw(self.path + os.sep, file)
        parsed_raw_out = []
        actual = False
        for linha in parsed_raw_actual:
            #actual = True
            if linha['PGN'] == 0x1ff16:
                actual = True
            if actual:
                parsed_raw_out.append(linha)
        
        parsed_raw = parsed_raw + parsed_raw_out
else: #Usa um sniffer local
    if dictionary_to_use == '':
        dictionary_to_use = '""'
    rawService = RawService(RawDataframeRequest('{"file_name":"", "bucket":"", "dictionary_to_use":' + dictionary_to_use + '}'), rawDataframService.path, rawDataframService.dictionaryService)
    self = rawService
    parsed_raw = self.parse_sniffer(file_sniffer)


parsed_bams = self.parse_bams(parsed_raw)
parsed_etps = self.parse_etps(parsed_raw)
parsed_raw  = parsed_bams + parsed_raw + parsed_etps
set_pgns    = self.find_set_pgns(parsed_raw)

# para filtrar os dados 
#file_name = file_list[0]
#file_name_str = file_name.split('_')[2]
#file_name_str = f"{file_name_str[4:]}/{file_name_str[2:4]}/{file_name_str[:2]}"
#file_name_str = datetime.strptime(file_name_str, '%d/%m/%y')
#parsed_raw = [item for item in parsed_raw if datetime.fromtimestamp(item['timestamp']) >= file_name_str]



ddop_dict, df_ddop = self.isobusService.get_ddop(parsed_bams + parsed_etps)
ddop_xml_dict, iso_proprietary_dict, XML_elements_dict, broken_reference_dict = self.isobusService.parse_ddop_xml(ddop_dict)
ddop_broken_references = False
for sc in broken_reference_dict:
    if broken_reference_dict[sc]:
        ddop_broken_references = ddop_broken_references | broken_reference_dict[sc]
        
if ddop_broken_references:
    print("Fazer uma tratativa para quando houver problemas de quebra de referências no ddop")

specific_dictionary     = [self.rawDataframeRequest.dictionary_to_use]
df_candictionary_filter = self.dictionaryService.get_df_candictionary()[self.dictionaryService.get_df_candictionary()['spn_dictionary'].isin(self.dictionaryService.standard_dictionary_list + specific_dictionary)]
df_candictionary_filter = df_candictionary_filter[df_candictionary_filter['pgn'].isin(set_pgns)]
df_candictionary_filter = df_candictionary_filter[df_candictionary_filter['spn'].notna()]



df_spns = self.dictionary_processor(parsed_raw, df_candictionary_filter, iso_proprietary_dict)
ddop_xml_dict, iso_proprietary_dict, XML_elements_dict, broken_reference_dict = self.isobusService.parse_ddop_xml(ddop_dict, df_spns)
level_formated_dict = self.isobusService.generate_iso_level_formated_dict(XML_elements_dict, df_spns, silent = False)
auto_generated_device_config = self.isobusService.generate_device_config(level_formated_dict, silent=False)
spn_dictionaries = rawService.spn_present_dictionaries(df_spns,df_candictionary_filter)
df_spns['actual_log'] = df_spns.index >= (list(df_spns[df_spns['pgn'] == 0x1ff16].index) + [len(df_spns)])[0]
print("Processado com sucesso")
# Out:
# PRCY8800KHPA03117_4C7525BE2A8E_240716_094255_2287_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_091923_2286_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_084923_2285_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_081923_2284_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_074923_2283_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_071923_2282_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_070631_2281_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_064021_2280_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_061211_2279_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_054211_2278_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_051211_2277_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_050754_2276_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_045259_2275_RAW  -  0.0.0.160
# PRCY8800KHPA03117_4C7525BE2A8E_240716_042259_2274_RAW  -  0.0.0.160
# ...

# %%
df_filename = pd.DataFrame()
ts_list = []
fn_list = []
for i in parsed_raw:
    ts_list.append(i['timestamp'])
    fn_list.append(i['file_name'])
df_filename['timestamp'] = ts_list
df_filename['file_name'] = fn_list
df_filename.index = -(np.array(df_filename.index)+1)
df = pd.concat([df_filename,df_spns[['timestamp']]]).sort_values('timestamp')
df['file_name'] = df['file_name'].ffill().bfill()
df_spns['file_name'] = df[df.index >= 0]['file_name']
print('Norma          '[:10],end = '')
print('PGN            '[:8],end = '')
print('PGN_H          '[:7],end = '')
print('SPN            '[:10],end = '')
print(colored('CAN1(x)          '[:8],'red'  ),end = '')
print(colored('CAN2(x)          '[:8],'green'),end = '')
print(colored('Disp(x)          '[:8],'blue' ),end = '')
print(colored('%              '[:6],'magenta' ),end = '')
print('Descrição - ',end = '')
print(colored('SourceList','blue' ))
lista_pgns = []
qty_total = len(parsed_raw)
sum_per = 0
for spn_name in df_spns.columns:
    if spn_name[:1] == '_':    
        try:
            print(colored((spn_dictionaries['dic_spn_dictionary'][spn_name] + "          ")[:9] + ' ','yellow'),end = '')
            print((str(int(df_spns[df_spns[spn_name].notna()].iloc[0]['pgn'])).replace('0x','').upper() + "          ")[:8],end = '')
            print(colored((str(hex(int(df_spns[df_spns[spn_name].notna()].iloc[0]['pgn']))).replace('0x','').upper() + "          ")[:7],'cyan'),end = '')
            print((spn_name.replace('_','').replace('.0','') + "          ")[:10],end = '')
            qty_0 = len(df_spns[(df_spns[spn_name].notna()) & (df_spns['port'] == 0)])
            qty_1 = len(df_spns[(df_spns[spn_name].notna()) & (df_spns['port'] == 1)])
            qty_2 = len(df_spns[(df_spns[spn_name].notna()) & (df_spns['port'] == 2)])
            print(colored((str(qty_0) + "          ")[:8],'red'  ),end = '')
            print(colored((str(qty_1) + "          ")[:8],'green'),end = '')
            print(colored((str(qty_2) + "          ")[:8],'blue' ),end = '')
            print(colored((str(round(100*(qty_0 + qty_1 + qty_2)/qty_total,2)) + "      ")[:6],'magenta' ),end = '')
            sum_per = sum_per + round(100*(qty_0 + qty_1 + qty_2)/qty_total,2)
            print(spn_dictionaries['dic_spn_lable'][spn_name], end  =' - ')
            print(colored(list(df_spns[(df_spns[spn_name].notna())]['source'].unique()),'blue' ))
        except:
            None

# %%
#Verifica se os descriptors vieram
print('Transferência dos descriptors: ')
if 'isobus_cmd' in df_spns:
    sc_tc = 247
    sc_list = list(df_spns[df_spns['isobus_cmd'].notna() & (df_spns['isobus_cmd'].apply(lambda x:str(x)[-1:]).isin(['0','1']))]['source'].unique())
    if sc_tc in sc_list:
        sc_list.remove(sc_tc)
    for sc in sc_list:
        resposta = ''
        command_list = df_spns[(df_spns.index > 0) & (df_spns['source'].isin([sc_tc,sc])) & df_spns['isobus_msn_type'].notna() & (df_spns['isobus_cmd'].apply(lambda x:str(x)[-1:]).isin(['0','1']))]['isobus_cmd'].unique()
        if (('11' in command_list) & ('51' in command_list) & ('61' in command_list) & ('71' in command_list) & ('81' in command_list) & ('91' in command_list)):
            resposta = 'Got descriptor'
        if (('11' in command_list) & ('51' in command_list) & ('61' not in command_list) & ('71' in command_list) & ('81' in command_list) & ('91' in command_list)):
            resposta = 'Lost descriptor' 
        if (('11' in command_list) & ('41' not in command_list) &('51' not in command_list) & ('61' not in command_list) & ('71' not in command_list) & ('81' in command_list) & ('91' in command_list)):
            resposta  = 'Preloaded descriptor'
        if resposta == '':
            print(sc, command_list)
        else:
            print(sc, '- ' + resposta)

# %%
#Imprime os descriptors em XML
for sc in XML_elements_dict.keys():
    print(sc)
    print(IsobusService().parse_dvc_name(XML_elements_dict[sc][0]['D']))
    print()
    print(sc, ddop_xml_dict[sc])
# Out:
# 240
# {'Industry_group': 'Agricultural and Forestry Equipment', 'Device_class': 'Non-specific System', 'Function': 'Tractor ECU', 'Manufacturer': 'John Deere', 'Identity_number': '122946'}
#
# ...

# %%
#Cria um dicionario de dataframes para os ddis. As chaves dos dataframes são a source e o element number
if 'isobus_msn_type' in df_spns:
    dict_df_iso = {}
    for sc in df_spns[df_spns['isobus_msn_type'] == 'Value']['source'].unique():
        dict_df_iso.update({sc:{}})
        for en in df_spns[(df_spns['isobus_msn_type'] == 'Value') & (df_spns['source'] == sc)]['EN'].unique():
            dict_df_iso[sc].update({en:pd.DataFrame()})
            dict_df_iso[sc][en]['timestamp'] = df_spns['timestamp']
            print(sc,en,list(df_spns[(df_spns['isobus_msn_type'] == 'Value') & (df_spns['source'] == sc)  & (df_spns['EN'] == en)]['DDI'].astype('int').unique()))
            for ddi in df_spns[(df_spns['isobus_msn_type'] == 'Value') & (df_spns['source'] == sc)  & (df_spns['EN'] == en)]['DDI'].astype('int').unique():
                dict_df_iso[sc][en][ddi] = df_spns[(df_spns['source'] == sc) & (df_spns['EN'] == en) & (df_spns['DDI'] == ddi) & (df_spns['isobus_msn_type'] == 'Value')]['PVV']
        print()
else:
    print("Sem mensagem de isobus")
# Out:
# 218 6.0 [135, 67]
# 218 7.0 [135, 67]
# 218 8.0 [135, 67]
# 218 9.0 [135, 67]
# 218 10.0 [135, 67]
# 218 11.0 [135, 67]
# 218 12.0 [135, 67]
# 218 13.0 [135, 67]
# 218 14.0 [135, 67]
# 218 15.0 [135, 67]
# 218 16.0 [135, 67]
# 218 17.0 [135, 67]
# 218 18.0 [135, 67]
# 218 19.0 [135, 67]
# 218 20.0 [135, 67]
# 218 21.0 [135, 67]
# 218 22.0 [135, 67]
# 218 23.0 [135, 67]
# 218 24.0 [135, 67]
# 218 25.0 [135, 67]
# 218 26.0 [135, 67]
# 218 27.0 [135, 67]
# 218 28.0 [135, 67]
# 218 29.0 [135, 67]
# 218 30.0 [135, 67]
# 218 31.0 [135, 67]
# 218 32.0 [135, 67]
# 218 33.0 [135, 67]
# 218 34.0 [135, 67]
# 218 35.0 [135, 67]
# 218 36.0 [135, 67]
# 218 1.0 [134, 135]
# 218 2.0 [161, 162, 290, 291, 179, 178, 141, 205, 206, 1, 2, 160, 134, 135, 158]
# 218 0.0 [141]
#
# 240 0.0 [306, 57363, 141, 57365, 57367, 57368]
# 240 1.0 [134, 135, 136]
# 240 2.0 [134, 135, 136]
# 240 4.0 [134, 135, 136]
# 240 10.0 [134, 135, 136]
# 240 11.0 [134, 135, 136]
# 240 12.0 [134, 135, 136]
# 240 6.0 [180]
# ...

# %%
df_spns[df_spns['DDI']==141]['PVV'].dropna().plot()
# Out:
# <Axes: >

# %%
df_spns_bkp = df_spns.copy()

# %%
df_spns = df_spns_bkp.copy()

# %%
df_spns = df_spns.sort_values('timestamp')
df_spns = df_spns.reset_index(drop = True)

# %%
sc = 218#int('da',16)
df_spns['SetpointRate[mm³/m²]'   ] = df_spns[(df_spns['DDI'] == 1  ) & (df_spns['source'] == sc)]['PVV']
df_spns['AppRate[mm³/m²]'        ] = df_spns[(df_spns['DDI'] == 2  ) & (df_spns['source'] == sc)]['PVV']
df_spns['SetpointRate[mg/m²]'    ] = df_spns[(df_spns['DDI'] == 6  ) & (df_spns['source'] == sc)]['PVV']
df_spns['AppRate[mg/m²]'         ] = df_spns[(df_spns['DDI'] == 7  ) & (df_spns['source'] == sc)]['PVV']
df_spns['Work_State'             ] = df_spns[(df_spns['DDI'] == 141) & (df_spns['source'] == sc)]['PVV']
df_spns['Section_Control_State'  ] = df_spns[(df_spns['DDI'] == 160) & (df_spns['source'] == sc)]['PVV']
df_spns['Target_Rate_Pressure[Pa]'   ] = df_spns[(df_spns['DDI'] == 193) & (df_spns['source'] == sc)]['PVV']
df_spns['Product_Rate_Pressure[Pa]'  ] = df_spns[(df_spns['DDI'] == 160) & (df_spns['source'] == sc)]['PVV']

# %%
def section_active(data):
    soma = 0
    #n_sec = 0
    for sec in range(1,len(data)*2+1):
        if int(data,16)>>((sec-1)*2)&0b11 == 1:
            soma = soma +1
        #if int(data,16)>>((sec-1)*2)&0b11 != 3:
        #    n_sec = n_sec +1 
    return soma
df_spns['DDI_161'] = df_spns[(df_spns['source'] == sc) & (df_spns['DDI'] == 161) & (df_spns['PVV'].notna())]['PVV']
df_spns['DDI_162'] = df_spns[(df_spns['source'] == sc) & (df_spns['DDI'] == 162) & (df_spns['PVV'].notna())]['PVV']
df_spns['DDI_163'] = df_spns[(df_spns['source'] == sc) & (df_spns['DDI'] == 163) & (df_spns['PVV'].notna())]['PVV']
df_spns['DDI_164'] = df_spns[(df_spns['source'] == sc) & (df_spns['DDI'] == 164) & (df_spns['PVV'].notna())]['PVV']

df_spns['DDI_161'] = df_spns['DDI_161'].dropna().apply(lambda x:('00000000'+hex(int(x))[2:])[-8:])
df_spns['DDI_162'] = df_spns['DDI_162'].dropna().apply(lambda x:('00000000'+hex(int(x))[2:])[-8:])
df_spns['DDI_163'] = df_spns['DDI_163'].dropna().apply(lambda x:('00000000'+hex(int(x))[2:])[-8:])
df_spns['DDI_164'] = df_spns['DDI_164'].dropna().apply(lambda x:('00000000'+hex(int(x))[2:])[-8:])

df_spns['DDI_161'] = df_spns['DDI_161'].ffill()
df_spns['DDI_162'] = df_spns['DDI_162'].ffill()
df_spns['DDI_163'] = df_spns['DDI_163'].ffill()
df_spns['DDI_164'] = df_spns['DDI_164'].ffill()

df_spns['DDI_161'] = df_spns['DDI_161'].fillna('ffffffff')
df_spns['DDI_162'] = df_spns['DDI_162'].fillna('ffffffff')
df_spns['DDI_163'] = df_spns['DDI_163'].fillna('ffffffff')
df_spns['DDI_164'] = df_spns['DDI_164'].fillna('ffffffff')
df_spns['Condensed_Work_State'] = df_spns['DDI_164'] + df_spns['DDI_163'] + df_spns['DDI_162'] + df_spns['DDI_161']
df_spns['Active_sections'] = df_spns['Condensed_Work_State'].apply(lambda x:section_active(x))

# %%
df_spns['Active_sections']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 2225867    0
# 2225868    0
# 2225869    0
# 2225870    0
# 2225871    0
# Name: Active_sections, Length: 2225872, dtype: int64

# %%
#pro caso de não ter isobus
df_iso = df_spns[['source','timestamp','_517','_584','_585',]]
df_iso = df_iso.reset_index(drop = True)
df_iso['Timestamp'] = pd.to_datetime(df_iso['timestamp'].astype('int'), unit='s')
df_iso = df_iso.sort_values('timestamp').reset_index(drop = True)

# %%
df_iso = df_spns[['source','timestamp','SetpointRate[mm³/m²]','AppRate[mm³/m²]','Work_State','Section_Control_State','Active_sections','_517','_584','_585','AppRate[mg/m²]','SetpointRate[mg/m²]']]
df_iso = df_iso.reset_index(drop = True)
df_iso['Timestamp'] = pd.to_datetime(df_iso['timestamp'].astype('int'), unit='s')
df_iso = df_iso.sort_values('timestamp').reset_index(drop = True)
df_iso.loc[(df_spns['AppRate[mg/m²]'] > df_iso['AppRate[mg/m²]'].quantile(.95)),'AppRate[mg/m²]'] = np.nan
df_iso['SetpointRate[mm³/m²]'     ] = df_iso['SetpointRate[mm³/m²]'].ffill().bfill()
df_iso['AppRate[mm³/m²]'          ] = df_iso['AppRate[mm³/m²]'].ffill().bfill()
df_iso['SetpointRate[mg/m²]'      ] = df_iso['SetpointRate[mg/m²]'].ffill().bfill()
df_iso['AppRate[mg/m²]'           ] = df_iso['AppRate[mg/m²]'].ffill().bfill()
df_iso['Work_State'               ] = df_iso['Work_State'].ffill().bfill()
df_iso['Active_sections'          ] = df_iso['Active_sections'].ffill().bfill()
# df_iso.loc[:,'Section_Control_State'    ] = df_iso['Section_Control_State'    ].ffill().bfill()
# df_iso.loc[:,'Speed[km/h]']               = df_iso['_84'].ffill().bfill()
df_iso['Speed[km/h]']               = df_iso['_517'].ffill().bfill().round(1)
df_iso['Work_State'] = df_iso['Work_State'].replace(1,'on')
df_iso['Work_State'] = df_iso['Work_State'].replace(0,'off')

# %%
#quando o pulverizador estiver ligado E alguma seção estiver ativa, está trabalhando
df_iso.loc[(df_iso['Work_State'] == 'on') & (df_iso['Active_sections'] != 0) & (df_iso['AppRate[mm³/m²]'] != 0), 'condicao'] = 1

#quando o pulverizador estiver desligado  ou ligado com sessão inativas, está deslocando
df_iso.loc[(df_iso['Work_State'] == 'off') | ((df_iso['Work_State'] == 'on') & (df_iso['Active_sections'] == 0)) | (df_iso['AppRate[mm³/m²]'] == 0) , 'condicao'] = 4

#quando a velocidade for menor que 0.5, ele está parado 
df_iso.loc[(df_iso['Speed[km/h]'] < 0.5), 'condicao'] = 2

#df_iso = df_iso[df_iso['condicao'].notna()]

# %%
df_iso['condicao'].value_counts()
# Out:
# 2.0    199272
# Name: condicao, dtype: int64

# %%
print('Sources de GPS encontradas')
for sc in df_iso[df_iso['_584'].notna()]['source'].unique():
    print(hex(sc)[2:])
# Out:
# Sources de GPS encontradas
# f9

# %%
#df_iso['Work_State'].dropna()

# %%
ECU_escolhida = int('f9',16)

# %%
#calculo das derivadas
def compute_derivatives(x, y):
        dx = np.gradient(x)
        dy = np.gradient(y)
        ddx = np.gradient(dx)
        ddy = np.gradient(dy)
        return dx, dy, ddx, ddy

def derivada(x, y):
        dx = np.gradient(x)
        dy = np.gradient(y)
        return dx, dy

# %%
#função da aceleração
def aceleracao(raw):
    if raw['dt'] != 0:
        raw.aceleracao = raw['dv']/raw['dt']
        return raw
    else:
        raw.aceleracao = 0
        return raw

# %%
df_iso['Speed[km/h]']               = df_iso['_517'].ffill().bfill().round(1)

# %%
#cálculo da aceleração
df_iso['velocidade'] = pd.Series()
df_xlr8 = pd.DataFrame()
df_iso['velocidade'] = df_spns['_517']
df_xlr8 = df_iso.loc[df_iso['velocidade'].notna()]
df_xlr8['dv'], df_xlr8['dt'] = derivada(df_xlr8['velocidade']/3.6, df_xlr8['timestamp'])
df_xlr8['aceleracao'] = pd.Series()
#df_xlr8 = df_xlr8.apply(aceleracao, axis = 1)
df_xlr8.loc[df_xlr8['dt'] != 0, 'aceleracao'] = df_xlr8['dv']/df_xlr8['dt']
df_xlr8.loc[df_xlr8['dt'] == 0, 'aceleracao'] = 0
df_iso['aceleracao'] = df_xlr8['aceleracao']
df_iso['aceleracao'] = df_iso['aceleracao'].ffill().bfill()
df_iso = df_iso.drop('velocidade', axis = 1)
# Out:
# C:\Users\tiago.chaves\AppData\Local\Temp\ipykernel_4112\4055632805.py:2: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# C:\Users\tiago.chaves\AppData\Local\Temp\ipykernel_4112\4055632805.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\tiago.chaves\AppData\Local\Temp\ipykernel_4112\4055632805.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
hover = ['condicao',
 'Speed[km/h]' ,'Timestamp', 'rotacao',   'aceleracao', 'raio2', 'tg2', 'velocidade%']
#'lat','lon' ,'modo_predict', 'Active_sections','SetpointRate[mm³/m²]','AppRate[mm³/m²]','torque',

# %%
file_list[0]
chassi_list = file_list[0].split('_')
data_texto ='25/01/2024'
chassis_texto = chassi_list[0]

# %%
df_iso['rotacao'] = df_spns['_190']
df_iso['rotacao'] = df_iso['rotacao'].ffill().bfill()
df_iso['torque'] = df_spns['_513']
df_iso['torque'] = df_iso['torque'].ffill().bfill()
df_iso['carga'] = df_spns['_92']
df_iso['carga'] = df_iso['carga'].ffill().bfill()
df_iso['consumo'] = df_spns['_183']
df_iso['consumo'] = df_iso['consumo'].ffill().bfill()

# %%
df_iso['lat'] = df_iso[(df_iso['source'] == ECU_escolhida)]['_584']
df_iso['lon'] = df_iso[(df_iso['source'] == ECU_escolhida)]['_585']

# %%
#conversão da latitude e longitude para cartesiano
def latlon_to_cartesian(lat, lon):
        R = 6371000  # Raio da Terra em metros
        lat = np.radians(lat)
        lon = np.radians(lon)
        x = R * np.cos(lat) * np.cos(lon)
        y = R * np.cos(lat) * np.sin(lon)
        return x, y
    
df_iso['x'], df_iso['y'] = latlon_to_cartesian(df_iso['lat'], df_iso['lon'])

# %%
df = pd.DataFrame()
df['y'] = df_iso[df_iso['source']==ECU_escolhida].loc[df_iso['lat'].notna()].reset_index()['y']
df['x'] = df_iso[df_iso['source']==ECU_escolhida].loc[df_iso['lat'].notna()].reset_index()['x']
df['dx'], df['dy'], df['ddx'], df['ddy'] = compute_derivatives(df['x'], df['y'])

# %%
#cálculo do raio de curvatura usando círculo osculador

#def curvature_radius(dx, dy, ddx, ddy):
#    numerator = (dx**2 + dy**2)**1.5
#    denominator = np.abs(dx * ddy - dy * ddx)
#    if (dx * ddy - dy * ddx):
#        R = numerator / denominator
#    else:
#        R = np.nan
#    return R


#for i in range(0, len(df)):
#    df['raio2'][i] = curvature_radius(df['dx'][i], df['dy'][i], df['ddx'][i], df['ddy'][i])
df['raio2'] = pd.Series()

df.loc[((df['dx']*df['ddy'] - df['dy']*df['ddx']) != 0), 'raio2'] = (np.square(df['dx']) + np.square(df['dy']))**1.5/np.abs(df['dx']*df['ddy'] - df['dy']*df['ddx'])
df['index'] = df_iso[df_iso['source']==ECU_escolhida].loc[df_iso['lat'].notna()].reset_index()['index']
df = df.set_index(['index'])
# Out:
# C:\Users\tiago.chaves\AppData\Local\Temp\ipykernel_4112\3584201359.py:12: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
df['index'] = df_iso[df_iso['source']==ECU_escolhida].loc[df_iso['lat'].notna()].reset_index()['index']
df = df.set_index(['index'])

# %%
df_iso['raio2'] = df['raio2']
df_iso['dx'] = df['dx']
df_iso['ddx'] = df['ddx']
df_iso['dy'] = df['dy']
df_iso['ddy'] = df['ddy']
df_iso['raio2'] = df_iso['raio2'].ffill()
df_iso['dx'] = df_iso['dx'].ffill()
df_iso['ddx'] = df_iso['ddx'].ffill()
df_iso['dy'] = df_iso['dy'].ffill()
df_iso['ddy'] = df_iso['ddy'].ffill()

# %%
#cálculo do ângulo de inclinação do terreo
df_alt = pd.DataFrame()
df_iso['altitude'] = pd.Series()
df_iso['altitude'] = df_spns['_580']
df_iso['x'] = df_iso['x'].ffill().bfill()
df_iso['y'] = df_iso['y'].ffill().bfill()
df_alt = df_iso.loc[(df_iso['altitude'].notna())]
df_alt = df_alt.drop(['dx', 'ddx', 'dy', 'ddy'], axis = 1)
df_alt['dx'] = df_alt['x'].diff()
df_alt['dy'] = df_alt['y'].diff()
df_alt['dz'] = df_alt['altitude'].diff()
df_alt = df_alt.reset_index()
df_alt['tg2'] = pd.Series()

#def tangente(raw):
#    if (np.square(raw['dx']) + np.square(raw['dy'])) != 0:
#        raw['tg2'] = raw['dz']/np.sqrt(np.square(raw['dx']) + np.square(raw['dy']))
#        return raw
#    else:
#        raw['tg2'] = 0
#        return raw

df_alt.loc[(np.square(df_alt['dx']) + np.square(df_alt['dy'])) != 0, 'tg2'] = df_alt['dz']/np.sqrt(np.square(df_alt['dx']) + np.square(df_alt['dy']))
df_alt.loc[(np.square(df_alt['dx']) + np.square(df_alt['dy'])) == 0, 'tg2'] = 0

#df_alt = df_alt.apply(tangente, axis = 1)


df_alt = df_alt.set_index('index')
df_iso['tg2'] = df_alt['tg2']
df_iso['tg2'] = df_iso['tg2'].ffill().bfill()
# Out:
# C:\Users\tiago.chaves\AppData\Local\Temp\ipykernel_4112\949732100.py:3: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# C:\Users\tiago.chaves\AppData\Local\Temp\ipykernel_4112\949732100.py:13: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
df_iso.loc[df_iso['tg2'] > df_iso['tg2'].quantile(0.95), 'tg2'] = np.nan
df_iso.loc[df_iso['tg2'] < df_iso['tg2'].quantile(0.05), 'tg2'] = np.nan
df_iso['tg2'] = df_iso['tg2'].ffill()

# %%
df_iso.loc[df_iso['aceleracao'] > df_iso['aceleracao'].quantile(0.95), 'aceleracao'] = np.nan
df_iso.loc[df_iso['aceleracao'] < df_iso['aceleracao'].quantile(0.05), 'aceleracao'] = np.nan
df_iso['aceleracao'] = df_iso['aceleracao'].ffill()

# %%
df_backup = df_iso

# %%
#tentativa de normalização mecanicamente
#df_iso['trq'] = pd.Series()
#df_iso.loc[(df_iso['torque'] >= 23) & (df_iso['torque'] <= 77), 'trq'] = 1
#df_iso.loc[df_iso['torque'] < 23, 'trq'] = 0
#df_iso.loc[df_iso['torque'] > 77, 'trq'] = 2

# %%
#df_iso = df_backup
df_iso.loc[df_iso['tg2']==0,'tg2'] = np.nan
df_iso['tg2'] = df_iso['tg2'].ffill().bfill()
#df_backup = df_iso.copy()
#df_iso.loc[(df_iso['Speed[km/h]'] < 9) & (df_iso['Speed[km/h]'] > 3), 'torque'] = 37
#df_iso.loc[df_iso['tg2'] > 0, 'torque'] = df_iso.loc[df_iso['tg2'] > 0, 'torque']

# %%
#df_dados = pd.read_csv('treino.csv')

# %%
df_treino = pd.DataFrame()
df_treino['rotacao'] = df_dados['rotacao']
df_treino['velocidade'] = df_dados['Speed[km/h]']
df_treino['torque'] = df_dados['torque']
df_treino['raio'] = df_dados['raio2']
df_treino['modo'] = df_dados['condicao']
df_treino['aceleracao'] = df_dados['aceleracao']
df_treino['tg'] = df_dados['tg2']
df_treino['consumo'] = df_dados['consumo']
df_treino['carga'] = df_dados['carga']

# %%
df_iso = pd.DataFrame()
df_iso = df_backup
df_iso.loc[df_iso['Speed[km/h]'] > df_iso['Speed[km/h]'].quantile(0.95), 'Speed[km/h]'] = np.nan
df_iso['Speed[km/h]'] = df_iso['Speed[km/h]'].ffill().bfill()
a = df_iso['Speed[km/h]'].max()
df_iso['velocidade%'] = df_iso['Speed[km/h]']/a
df_iso['velocidade%'] = df_iso['velocidade%'].ffill().bfill()

# %%
df_iso['condicao'] = 0

# %%
df_teste = pd.DataFrame()
df_teste['rotacao'] = df_iso['rotacao']
df_teste['velocidade'] = df_iso['Speed[km/h]']
df_teste['torque'] = df_iso['torque']
df_teste['raio'] = df_iso['raio2']
df_teste['modo'] = df_iso['condicao']
df_teste['aceleracao'] = df_iso['aceleracao']
df_teste['tg'] = df_iso['tg2']
df_teste['consumo'] = df_iso['consumo']
df_teste['carga'] = df_iso['carga']
df_teste['velocidade%'] = df_iso['velocidade%']
df_teste['velocidade%'] = df_teste['velocidade%'].ffill().bfill()
df_teste['torque'] = df_teste['torque'].ffill().bfill()

# %%
df_treino['timestamp'] = df_dados['timestamp']
dias = [[1715731231, 1715817571], [1716768031, 1716854371], [1713916819, 1714003191], [1714003192, 1714089591], [1714435219, 1714521591], [1715299219, 1715385591], [1716854419, 1716940791], [1717632019, 1717718391]]
df_treino['velocidade%'] = pd.Series()
df_treino.loc[df_treino['velocidade'] > df_treino['velocidade'].quantile(0.925), 'velocidade'] = np.nan
#df_treino['velocidade'] = df_treino['velocidade'].ffill().bfill()
for i in dias:
#    df_treino.loc[(df_treino['timestamp'] > i[0]) & (df_treino['timestamp'] < i[1]) & (df_treino['velocidade'] > df_treino.loc[(df_treino['timestamp'] > i[0]) & (df_treino['timestamp'] < i[1])]['velocidade'].quantile(0.90)), 'velocidade'] = np.nan
    df_treino.loc[(df_treino['timestamp'] > i[0]) & (df_treino['timestamp'] < i[1]), 'velocidade'] = df_treino.loc[(df_treino['timestamp'] > i[0]) & (df_treino['timestamp'] < i[1])]['velocidade'].ffill().bfill()
    a = df_treino.loc[(df_treino['timestamp'] > i[0]) & (df_treino['timestamp'] < i[1])]['velocidade'].max()
    df_treino.loc[(df_treino['timestamp'] > i[0]) & (df_treino['timestamp'] < i[1]), 'velocidade%'] = df_treino['velocidade']/a

df_treino['velocidade%'] = df_treino['velocidade%'].ffill().bfill()
df_treino = df_treino.drop('timestamp', axis = 1)
# Out:
# C:\Users\tiago.chaves\AppData\Local\Temp\ipykernel_4112\363362425.py:3: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
df_iso['raio2'] = df_iso['raio2'].ffill().bfill()
df_iso.loc[df_iso['raio2'] <= 8, 'raio'] = 0
df_iso.loc[df_iso['raio2'] > 8, 'raio'] = 1

# %%
df_teste['raio'] = df_teste['raio'].ffill().bfill()
df_treino['raio'] = df_treino['raio'].ffill().bfill()
df_treino = df_treino.loc[df_treino['modo'].notna()]

# %%
#binarização do raio
df_teste.loc[df_teste['raio'] <= 8, 'raio'] = 0
df_teste.loc[df_teste['raio'] > 8, 'raio'] = 1
df_treino.loc[df_treino['raio'] <= 8, 'raio'] = 0
df_treino.loc[df_treino['raio'] > 8, 'raio'] = 1

# %%
#df_teste.loc[df_teste['rotacao'] < 1000, 'rotacao'] = 0
#df_teste.loc[(df_teste['rotacao'] >= 1000) & (df_teste['rotacao'] <= 1600), 'rotacao'] = 1
#df_teste.loc[df_teste['rotacao'] > 1600, 'rotacao'] = 2
#
#df_treino.loc[df_treino['rotacao'] < 1000, 'rotacao'] = 0
#df_treino.loc[(df_treino['rotacao'] >= 1000) & (df_treino['rotacao'] <= 1600), 'rotacao'] = 1
#df_treino.loc[df_treino['rotacao'] > 1600, 'rotacao'] = 2

# %%
#df_teste.loc[df_teste['velocidade'] < 3, 'velocidade'] = 0
#df_teste.loc[(df_teste['velocidade'] >= 3) & (df_teste['velocidade'] <= 8.5), 'velocidade'] = 1
#df_teste.loc[df_teste['velocidade'] > 8.5, 'velocidade'] = 2
#
#df_treino.loc[df_treino['velocidade'] < 3, 'velocidade'] = 0
#df_treino.loc[(df_treino['velocidade'] >= 3) & (df_treino['velocidade'] <= 8.5), 'velocidade'] = 1
#df_treino.loc[df_treino['velocidade'] > 8.5, 'velocidade'] = 2

# %%
colunas = [ 'rotacao','aceleracao', 'consumo', 'carga', 'torque',]
#'consumo', 'carga', 'torque',

# %%
#def remover_outliers(df_teste, colunas):
#    indices_para_remover = set()
#    
#    for coluna in colunas:
#        Q1 = df_teste[coluna].quantile(0.05)
#        Q3 = df_teste[coluna].quantile(0.95)
#        IQR = Q3 - Q1
#        limite_inferior = Q1 - 1.5 * IQR
#        limite_superior = Q3 + 1.5 * IQR
#        outliers = df_teste[(df_teste[coluna] < limite_inferior) | (df_teste[coluna] > limite_superior)].index
#        indices_para_remover.update(outliers)
#
#    df_teste = df_teste.drop(indices_para_remover)
#    return df_teste
#df_teste = remover_outliers(df_teste, colunas)
#df_treino = remover_outliers(df_treino, colunas)

# %%
# SGD - 91.6%
# ET 96.1%

df_treino[colunas] = np.log1p(df_treino[colunas])
df_teste[colunas] = np.log1p(df_teste[colunas])

# %%
df_teste['aceleracao'] = df_teste['aceleracao'].ffill().bfill()

# %%
#separação dos dados de treinamento e de predição

#df_iso = df_backup
df_treino['timestamp'] = df_dados['timestamp']
df_teste['timestamp'] = df_dados['timestamp']
#df_treino = df_treino.loc[(df_treino['timestamp'] < 1713968878) | (df_treino['timestamp'] > 1713970310)]
#df_treino = df_treino.loc[(df_treino['timestamp'] < 1714490465) | (df_treino['timestamp'] > 1714494545)]
#df_treino = df_treino.loc[(df_treino['timestamp'] < 1716768031) | (df_treino['timestamp'] > 1716854371)] #tira o dia 27/05
#df_treino = df_treino.loc[(df_treino['timestamp'] < 1715731231) | (df_treino['timestamp'] > 1715817571)] #tira o dia 15/05
df_treino = df_treino.loc[(df_treino['timestamp'] < 1716803760) | (df_treino['timestamp'] > 1716813360)] #parte do 27/05
#df_teste = df_teste.loc[(df_teste['timestamp'] < 1716803760) | (df_teste['timestamp'] > 1716813360)]
df_treino = df_treino.drop('timestamp', axis = 1)
df_teste = df_teste.drop('timestamp', axis = 1)
#
#df_teste = df_teste.loc[df_teste['modo'].notna()]
#df_treino = df_treino.loc[df_treino['modo'].notna()]

weight_factor = 1
#df_teste['raio'] *= weight_factor
#df_treino['raio'] *= weight_factor
y_treino = df_treino['modo']
x_treino = df_treino.drop('modo', axis = 1)
y_teste = df_teste['modo']
x_teste = df_teste.drop('modo', axis = 1)
x_treino['velocidade'] = x_treino['velocidade'].ffill().bfill()
x_teste['velocidade'] = x_teste['velocidade'].ffill().bfill()

# %%
x_treino = x_treino.drop(['velocidade'], axis = 1)

# %%
#modelo = ExtraTreesClassifier(n_estimators = 100, max_depth = 30, min_samples_split = 10, min_samples_leaf = 4)
#modelo.fit(x_treino, y_treino)
#resultado = modelo.score(x_teste, y_teste)
#print(f'Acurácia: {resultado}')

# %%
x_treino.loc[x_treino['velocidade'].isna()]
# Out:
# Empty DataFrame
# Columns: [rotacao, velocidade, torque, raio, aceleracao, tg, consumo, carga, velocidade%]
# Index: []

# %%
x_treino['velocidade%'] = x_treino['velocidade%']*10
x_teste['velocidade%'] = x_teste['velocidade%']*10

# %%
x_treino['velocidade%'] = x_treino['velocidade%'].ffill().bfill()

# %%
modelo_sgd = SGDClassifier()
modelo_sgd.fit(x_treino, y_treino)
##resultado = modelo_1.score(x_teste, y_teste)
#print(f'Acurácia: {resultado}')
# Out:
# SGDClassifier()

# %%
dump(modelo_sgd, 'modelo_2v.joblib')
# Out:
# ['modelo_2v.joblib']

# %%
#base_estimators = [
#    ('extra_trees', ExtraTreesClassifier(n_estimators=100, max_depth = 30, min_samples_split = 10, min_samples_leaf = 4)),
#    ('sgd', SGDClassifier(max_iter=1000, tol=1e-3, random_state=42))
#]
#
#meta_estimator = LogisticRegression()
#
#stacking_clf = StackingClassifier(
#    estimators=base_estimators,
#    final_estimator=meta_estimator,
#    passthrough=False  # Se True, as características originais também são passadas para o meta-estimador
#)
#
#stacking_clf.fit(x_treino, y_treino)
#resultado = stacking_clf.score(x_teste, y_teste)
#print(f'Acurácia: {resultado}')

# %%
#modelo_1.partial_fit(x_teste, y_teste)

# %%
#modelo_2 = load('modelo_sem_nada.joblib')

# %%
#resultado = modelo.score(x_teste, y_teste)
#print(f'Acurácia: {resultado}')

# %%
dump(modelo_sgd, 'modelo_velocidade%.joblib')
# Out:
# ['modelo_velocidade%.joblib']

# %%
#df_teste['modo_predict'] = pd.Series()
df_teste['modo_predict'] = modelo_sgd.predict(x_teste)

# %%
df_iso['modo_predict'] = pd.Series()
df_iso['modo_predict'] = df_teste['modo_predict']
# Out:
# C:\Users\tiago.chaves\AppData\Local\Temp\ipykernel_4112\3126088563.py:1: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
df_iso.loc[df_iso['modo_predict'] == 2, 'modo_predict'] = 1

# %%
df_iso.loc[df_iso['Speed[km/h]'] >= (df_iso['Speed[km/h]'].mean() + df_iso['Speed[km/h]'].max()/3), 'modo_predict'] = 4

# %%
#garantia de que as curvas vão estar classificadas como deslocamento
df_iso.loc[df_iso['raio2'] <= 9, 'modo_predict'] = 4

# %%
def histerese(i, modo, t):
    j = i
    modo_antigo = modo
    while (df_iso['modo_predict'][i] == df_iso['modo_predict'][j+1]) and j != len(df_iso)-2 :
        j += 1
    tempo = df_iso['timestamp'][j] - df_iso['timestamp'][i]
    if tempo <= t:               
        for a in range(i, j+1):
            df_iso.loc[a, 'modo_predict'] = modo_antigo

def histerese_especifica(df_iso):
    for i in range(4, len(df_iso) - 4):
        if df_iso['modo_predict'][i] != df_iso['modo_predict'][i-1]:
            if df_iso['modo_predict'][i] == 2:
                continue
            elif df_iso['modo_predict'][i] == 1:
                histerese(i, 4, 8)
            elif df_iso['modo_predict'][i] == 4:
                if (df_iso['raio'][i-4]+df_iso['raio'][i-3]+df_iso['raio'][i-2]+df_iso['raio'][i-1]+df_iso['raio'][i]+df_iso['raio'][i+1]+df_iso['raio'][i+2]+df_iso['raio'][i+3]+df_iso['raio'][i+4]) < 5:
                    histerese(i, 1, 3)
                else:
                    histerese(i, 1, 8)

histerese_especifica(df_iso)

# %%
#histerese

for i in range(1, len(df_iso)):
    if df_iso['modo_predict'][i] != df_iso['modo_predict'][i-1]:
        j = i
        modo_antigo = df_iso['modo_predict'][i-1]
        while (df_iso['modo_predict'][i] == df_iso['modo_predict'][j+1]) and j != len(df_iso)-2 :
            j += 1
        tempo = df_iso['timestamp'][j] - df_iso['timestamp'][i]
        if tempo <= 4:
            #df_iso.loc[(df_iso['modo_predict'] >= i) & (df_iso['modo_predict'] <= j) ]['modo_predict'] = modo_antigo
            for a in range(i, j+1):
                df_iso.loc[a, 'modo_predict'] = modo_antigo

# %%
operacao = 'Condição'
texto = chassis_texto + " " + data_texto + " " + operacao
filename = chassis_texto + '_' +  data_texto.replace('/','') + '_' + operacao.replace(' ','') + '.html'
# ECU_escolhida = int('1c',16)
df_iso['lat'] = df_iso[(df_iso['source'] == ECU_escolhida)]['_584']
df_iso['lon'] = df_iso[(df_iso['source'] == ECU_escolhida)]['_585']

fig = px.scatter_mapbox(df_iso[::1], hover_data = hover, lat="lat", lon="lon", color ='modo_predict', zoom=15, height=1000)
fig.update_layout(
    mapbox_style="white-bg",
    mapbox_layers=[{"below": 'traces',"sourcetype": "raster","source": ["https://mts1.google.com/vt/lyrs=y&hl=en&src=app&x={x}&y={y}&z={z}&s=G"]}])

fig.update_layout(title=dict(text=texto))
#fig.update_layout(margin={"r":0,"t":1.1,"l":0,"b":0})

#fig.write_html(filename)
fig.show()

# %%
operacao = 'Application Rate'
texto = chassis_texto + " " + data_texto + " " + operacao
filename = chassis_texto + '_' +  data_texto.replace('/','') + '_' + operacao.replace(' ','') + '.html'

df_iso['lat'] = df_iso[(df_iso['source'] == ECU_escolhida)]['_584']
df_iso['lon'] = df_iso[(df_iso['source'] == ECU_escolhida)]['_585']


fig = px.scatter_mapbox(df_iso[::1], hover_data = hover, lat="lat", lon="lon", color ='AppRate[mm³/m²]', color_continuous_scale=[(0.00, "red"),(0.5, "yellow"),(1, "green")], zoom=15, height=1000)
fig.update_layout(
    mapbox_style="white-bg",
    mapbox_layers=[{"below": 'traces',"sourcetype": "raster","source": ["https://mts1.google.com/vt/lyrs=y&hl=en&src=app&x={x}&y={y}&z={z}&s=G"]}])

fig.update_layout(title=dict(text=texto))
# fig.update_layout(margin={"r":0,"t":1.1,"l":0,"b":0})

#fig.write_html(filename)
fig.show()

# %%
operacao = 'Work State'
texto =  chassis_texto + " " + data_texto + " " + operacao
filename = chassis_texto + '_' +  data_texto.replace('/','') + '_' + operacao.replace(' ','') + '.html'
# ECU_escolhida = int('1c',16)
df_iso['lat'] = df_iso[(df_iso['source'] == ECU_escolhida)]['_584']
df_iso['lon'] = df_iso[(df_iso['source'] == ECU_escolhida)]['_585']

fig = px.scatter_mapbox(df_iso[::1], hover_data = hover, lat="lat", lon="lon", color ='Work_State', color_discrete_map={"on": "green","off": "red"} , zoom=15, height=1000)
fig.update_layout(
    mapbox_style="white-bg",
    mapbox_layers=[{"below": 'traces',"sourcetype": "raster","source": ["https://mts1.google.com/vt/lyrs=y&hl=en&src=app&x={x}&y={y}&z={z}&s=G"]}])

fig.update_layout(title=dict(text=texto))
#fig.update_layout(margin={"r":0,"t":1.1,"l":0,"b":0})

#fig.write_html(filename)
fig.show()

# %%
df_treino[colunas].hist(bins=30, figsize=(15, 10), layout=(len(colunas)//3 + 1, 3))
plt.suptitle('Distribuição dos Dados Após a Normalização')
plt.show()

# %%
#df_teste = df_teste.drop('torque', axis = 1)
#x_teste = x_teste.drop('modo_predict', axis = 1)
df_treino = df_treino.drop('carga', axis = 1)
#df_teste = df_teste.drop('tg', axis = 1)
#df_treino = df_treino.drop('tg', axis = 1)
#df_teste = df_teste.drop('aceleracao', axis = 1)
#df_treino = df_treino.drop('aceleracao', axis = 1)

# %%
#gráfico de TP x FP


from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt
from itertools import cycle


# Binarizar as classes para a abordagem one-vs-rest
y_bin = label_binarize(y_treino, classes=[1, 2, 4])
n_classes = y_bin.shape[1]

 
# Inicializar diferentes modelos
#models = {'ExtraTrees': ExtraTreesClassifier()}
# Treinar e avaliar cada modelo

modelo.fit(x_treino, y_treino)
y_score = modelo.predict_proba(x_teste)
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    if np.sum(y_teste == i) == 0:
        print(f'Classe {i} não tem amostras positivas no conjunto de teste.')
        continue
    fpr[i], tpr[i], _ = roc_curve(label_binarize(y_teste, classes=[1, 2, 4])[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
plt.figure()
colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    if i in fpr:  # Verificar se a classe foi processada
        plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve (class {i}) (area = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic for model')
plt.legend(loc='lower right')
plt.show()
for i in range(n_classes):
    if i in roc_auc:
        print(f'model Class {i} ROC AUC: {roc_auc[i]:.2f}')
# Out:
# Classe 0 não tem amostras positivas no conjunto de teste.
# model Class 1 ROC AUC: 1.00
# model Class 2 ROC AUC: 0.99
